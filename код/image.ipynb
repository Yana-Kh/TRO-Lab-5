# %% [markdown]
# ## Задание:
# Найти какое-либо изображение в сети Интернет. Создать ноутбук, в котором будет
# отображено выбранное изображение средствами библиотеки matplotlib по URL из сети
# Интернет.

# %% [markdown]
# ### Решение задачи:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
from io import BytesIO
import requests

plt.figure(figsize=(20, 10))

response = requests.get('https://sun2-14.userapi.com/impg/Urz9jcVAR4N20wCLZN8LLYp0GmS4-HpCQ2Dzdw/uAPiFyp0zds.jpg?size=1280x960&quality=95&sign=dbca56f6c75304da8e1da555b95434c0&type=album')
img = Image.open(BytesIO(response.content))
plt.imshow(img)
